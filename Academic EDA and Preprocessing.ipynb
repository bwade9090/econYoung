# %%
# %cd drive/MyDrive/Colab\ Notebooks/EconYP
# Out:
# /content/drive/MyDrive/Colab Notebooks/EconYP

# %%
# !sudo apt-get update -qq
# !sudo apt-get install fonts-nanum* -qq
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %%
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
# Out:
# NanumBarunGothic

# %%
plt.rc('font', family=font_name)
fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns

# %%
sns.set(font=font_name, 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
import pandas as pd

# %%
pd.Series([1, -1, 0, 5, -5]).plot(title="한글폰트")

# %%
import numpy as np
import os

# %% [markdown]
# # Original Panel

# %% [markdown]
# ## 2차(2008년)

# %%
df_2 = pd.read_csv('data/raw/ypdata_w{0:02d}.csv'.format(2), index_col='sampid')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (75,76,78,79,516,517,557,558,728,746,764,808,820,831,832,833,843,845,855,857) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2.columns
# Out:
# Index(['w01hid', 'w02hid', 'w1', 'w2', 'gender', 'yob', 'w02edu', 'w02eduy',
#        'w02edum', 'w01type',
#        ...
#        'y02h446', 'y02h447', 'y02h448', 'y02h449', 'y02h450', 'y02h451',
#        'y02h452', 'y02h453', 'y02h454', 'y02h455'],
#       dtype='object', length=1379)

# %%
# 학교 유형
sns.countplot(df_2.y02a023).set_title('학교 유형')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, '학교 유형')

# %%
# 주간 고등학교로 필터링
df_2 = df_2[df_2.y02a023 == 3]

# %%
len(df_2)
# Out:
# 2321

# %%
# 고등학교 유형
sns.countplot(df_2.y02a030).set_title('고등학교 유형')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, '고등학교 유형')

# %%
# 일반계/인문계로 필터링
df_2 = df_2[df_2.y02a030 == 1]

# %%
len(df_2)
# Out:
# 1789

# %%
# 학년 구성
sns.countplot(df_2.y02a037)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 전반적 성적
sns.countplot(df_2.y02a059)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 언어
sns.countplot(df_2.y02a060)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 수학
sns.countplot(df_2.y02a061)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 과학
sns.countplot(df_2.y02a062)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 사회
sns.countplot(df_2.y02a063)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 외국어
sns.countplot(df_2.y02a064)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 학업 관련 column만
df_2 = df_2.filter(regex='^y.*a[0-9]', axis=1)

# %%
df_2.columns
# Out:
# Index(['y02a001', 'y02a002', 'y02a003', 'y02a022', 'y02a023', 'y02a024',
#        'y02a025', 'y02a026', 'y02a027', 'y02a028',
#        ...
#        'y02a588', 'y02a589', 'y02a590', 'y02a591', 'y02a592', 'y02a593',
#        'y02a594', 'y02a595', 'y02a596', 'y02a597'],
#       dtype='object', length=217)

# %%
df_2.index
# Out:
# Int64Index([    1,    13,    18,    19,    21,    22,    24,    26,    27,
#                32,
#             ...
#             10146, 10153, 10167, 10181, 10194, 10196, 10198, 10200, 10201,
#             10204],
#            dtype='int64', name='sampid', length=1789)

# %% [markdown]
# ## 2019년(13차)

# %%
df_13 = pd.read_csv('data/raw/ypdata_w{0:02d}.csv'.format(13), index_col='sampid')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (76,77,140,141,261,262,997,998,1205,1236,1267,1298,1329,1368,1383,1384,1385,1399,1400,1401,1415,1417,1455,1456,1709,1710) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 고등학교 기록 있는 청년만 필터링
df_13 = df_13.loc[df_2.index]

# %%
len(df_13)
# Out:
# 1789

# %%
# 응답여부
sns.countplot(df_13.w13)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 응답자유형
sns.countplot(df_13.w13type).set_title('응답자 유형')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-dacb5135069c> in <module>()
#       1 # 응답자유형
# ----> 2 sns.countplot(df_13.w13type).set_title('응답자 유형')
#
# NameError: name 'df_13' is not defined

# %%
# 현직장 입사시기
sns.countplot(df_13.y13b106)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 임금유형
sns.countplot(df_13.y13b224)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_13['y13wage'] = np.nan

# %%
def convert_to_annual_salary(row):
  if row['y13b224'] == 1:
    row['y13wage'] = row['y13b225']
  elif row['y13b224'] == 2:
    row['y13wage'] = row['y13b225'] * 12
  elif row['y13b224'] == 3:
    row['y13wage'] = row['y13b225'] * 52
  elif row['y13b224'] == 4:
    row['y13wage'] = row['y13b225'] * 52 * 5
  elif row['y13b224'] == 5:
    row['y13wage'] = row['y13b225'] * 52 * 40
  else:
    row['y13wage'] = np.nan
  
  if row['y13b225'] > 9e6:
    row['y13wage'] = np.nan
  
  return row

# %%
df_13 = df_13.apply(convert_to_annual_salary, axis=1)

# %%
df_13.y13wage.max()
# Out:
# 12000.0

# %%
df_13.y13wage.min()
# Out:
# 0.0

# %%
# 임금
sns.boxplot(df_13.y13wage)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(df_13.y13wage)

# %%
# 부채유무
sns.countplot(df_13.y13b226)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 부채금액
sns.histplot(df_13[df_13.y13b227 < 9e6]['y13b227'])

# %%
# 학업 관련 columns 제거
df_13 = df_13.drop(df_13.filter(regex='^y.*a[0-9]', axis=1).columns, axis=1)

# %%
len(df_2.columns), len(df_13.columns)
# Out:
# (217, 1713)

# %% [markdown]
# ## Join

# %%
df = df_2.join(df_13)

# %%
len(df.columns)
# Out:
# 1930

# %%
import pickle
with open('data/academic_YP_join.pkl', 'wb') as f:
  pickle.dump(df, f)
